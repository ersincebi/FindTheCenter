# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from collections import deque

# %%
batch_size = 32
discount_rate = 0.95
optimizer = keras.optimizers.Adam(lr=1e-3)
loss_fn = keras.losses.mean_squared_error

replay_memory = deque(maxlen=2000)

env = gym.make('CartPole-v1')

env.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

rewards = [] 
best_score = 0

keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

env = gym.make("CartPole-v1")
input_shape = [4] # == env.observation_space.shape
n_outputs = 2 # == env.action_space.n

model = keras.models.Sequential([
    keras.layers.Dense(32, activation="elu", input_shape=input_shape),
    keras.layers.Dense(32, activation="elu"),
    keras.layers.Dense(n_outputs)
])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-79738f57734d> in <module>
#       4 loss_fn = keras.losses.mean_squared_error
#       5
# ----> 6 replay_memory = deque(Maxlen=2000)
#       7
#       8 env = gym.make('CartPole-v1')
#
# TypeError: 'Maxlen' is an invalid keyword argument for deque()

# %%
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
def sample_experiences(batch_size):
    indices = np.random.randint(len(replay_memory), size=batch_size)
    batch = [replay_memory[index] for index in indices]
    states, actions, rewards, next_states, dones = [
        np.array([experience[field_index] for experience in batch])
        for field_index in range(5)]
    return states, actions, rewards, next_states, dones

# %%
def training_step(batch_size):
    experiences = sample_experiences(batch_size)
    states, actions, rewards, next_states, dones = experiences
    next_Q_values = model.predict(next_states)
    max_next_Q_values = np.max(next_Q_values, axis=1)
    target_Q_values = (rewards +
                       (1 - dones) * discount_rate * max_next_Q_values)
    target_Q_values = target_Q_values.reshape(-1, 1)
    mask = tf.one_hot(actions, n_outputs)
    with tf.GradientTape() as tape:
        all_Q_values = model(states)
        Q_values = tf.reduce_sum(all_Q_values * mask, axis=1, keepdims=True)
        loss = tf.reduce_mean(loss_fn(target_Q_values, Q_values))
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

# %%
for episode in range(600):
    obs = env.reset()    
    for step in range(200):
        epsilon = max(1 - episode / 500, 0.01)
        if np.random.rand() < epsilon:
            action = np.random.randint(env.action_space.n)
        else:
            Q_values = model.predict(obs[np.newaxis])
            action = np.argmax(Q_values[0])

        obs, reward, done, info = env.step(action)
        
        if done:
            break
            
    rewards.append(step)
    
    if step > best_score:
        best_weights = model.get_weights()
        best_score = step
    if episode > 50:
        training_step(batch_size)

model.set_weights(best_weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aeca081400cc> in <module>
#      20         best_score = step
#      21     if episode > 50:
# ---> 22         training_step(batch_size)
#      23
#      24 model.set_weights(best_weights)
#
# <ipython-input-5-bbe00158a8e6> in training_step(batch_size)
#       1 def training_step(batch_size):
# ----> 2     experiences = sample_experiences(batch_size)
#       3     states, actions, rewards, next_states, dones = experiences
#       4     next_Q_values = model.predict(next_states)
#       5     max_next_Q_values = np.max(next_Q_values, axis=1)
#
# <ipython-input-4-46a6d7660901> in sample_experiences(batch_size)
#       1 def sample_experiences(batch_size):
# ----> 2     indices = np.random.randint(len(replay_memory), size=batch_size)
#       3     batch = [replay_memory[index] for index in indices]
#       4     states, actions, rewards, next_states, dones = [
#       5         np.array([experience[field_index] for experience in batch])
#
# NameError: name 'replay_memory' is not defined

# %%
plt.figure(figsize=(8, 4))
plt.plot(rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Sum of rewards", fontsize=14)
plt.show()
# Out:
# Saving figure dqn_rewards_plot-1
